# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D,MaxPooling2D
from tensorflow.keras.utils import to_categorical

# %%
import random
import time

# %%
path = "./germany_dataset/train.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId  \
# 0     27      26       5       5      22      20       20
# 1     28      27       5       6      23      22       20
# 2     29      26       6       5      24      21       20
# 3     28      27       5       6      23      22       20
# 4     28      26       5       5      23      21       20
#
#                              Path
# 0  Train/20/00020_00000_00000.png
# 1  Train/20/00020_00000_00001.png
# 2  Train/20/00020_00000_00002.png
# 3  Train/20/00020_00000_00003.png
# 4  Train/20/00020_00000_00004.png

# %%
df.describe()
# Out:
#               Width        Height        Roi.X1        Roi.Y1        Roi.X2  \
# count  39209.000000  39209.000000  39209.000000  39209.000000  39209.000000
# mean      50.835880     50.328930      5.999515      5.962381     45.197302
# std       24.306933     23.115423      1.475493      1.385440     23.060157
# min       25.000000     25.000000      0.000000      5.000000     20.000000
# 25%       35.000000     35.000000      5.000000      5.000000     29.000000
# 50%       43.000000     43.000000      6.000000      6.000000     38.000000
# 75%       58.000000     58.000000      6.000000      6.000000     53.000000
# max      243.000000    225.000000     20.000000     20.000000    223.000000
#
#              Roi.Y2       ClassId
# count  39209.000000  39209.000000
# mean      44.728379     15.788390
# std       21.971145     12.013238
# min       20.000000      0.000000
# 25%       30.000000      5.000000
# 50%       38.000000     12.000000
# 75%       52.000000     25.000000
# max      205.000000     42.000000

# %%
# All Variables declaration to use same code for different datasets
num_of_classes = df["ClassId"].nunique()
resize_x  = 15
resize_y  = 15
num_of_channels = 3
directory = "./germany_dataset/"
Epochs=50
train_length = len(df)

# %%
print("Total Training Examples : ",len(df))
# Out:
# Total Training Examples :  39209

# %%
# Sample Images and there crop according to data given in csv
num_rows = 5
num_cols = 2
fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 20))
total_images = []
for i in range(5):
    integer = random.randint(0,train_length)
    total_images.append(df.iloc[integer].values)
total_images = list(total_images)
for i,val in enumerate(total_images):
    row = i
    col=0
    ax = axes[row, col]
    img = Image.open(directory+val[7])
    ax.imshow(img)
    img = img.crop((val[2],val[3],val[4],val[5]))
    ax = axes[row,col+1]
    ax.imshow(img)
    ax.set_title(f'Image {i + 1}')
    ax.axis('off')

# %%
#Statistics of Data
print("Total Training Examples : ",len(df))
values = df["ClassId"].value_counts()
x_labels = [str(x) for x in range(num_of_classes)]
y_labels = []
for x in range(num_of_classes):
    y_labels.append(values[x])
plt.figure(figsize=(15, 6))
plt.bar(x_labels,y_labels,width=0.5)
plt.title('Bar Graph')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# Total Training Examples :  39209

# %%
# Necessary Functions

def get_max_index(arr):
    length = len(arr)
    mini = 0
    value = 0
    for i,val in enumerate(arr):
        if mini < val :
            mini = val
            value = i
    return value

def Predict_for_single_example(model,img):
    img  = np.array(img)
    img  = tf.convert_to_tensor(img,dtype=float)
    img = img/255.0
    img = tf.expand_dims(img, axis=0)
    probability = model.predict(img)
    value = get_max_index(probability[0])
    return value
    
def Predict_for_Multiple_examples(model,images):
    img = np.array(images)
    img = tf.convert_to_tensor(img,dtype=float)
    img = img/255.0
    probability = model.predict(img)
    values = []
    for val in probability:
        values.append(get_max_index(val))
    return values

# %%
class Data:
    def __init__(self,df,size_x,size_y):
        self.df = df
        self.root = directory
        self.resize_x = size_x
        self.resize_y = size_y
    
    def Do_Crop(self,path,x1,y1,x2,y2):
        img = Image.open(self.root+path)
        img = img.crop((x1,y1,x2,y2))
        return img.resize((self.resize_x,self.resize_y))
    
    def Row_Data(self,row):
        self.X.append(self.Do_Crop(row[7],row[2],row[3],row[4],row[5]))
        self.Y.append(int(row[6]))
    
    def Get_Data(self):
        self.X = []
        self.Y = []
        for index, row in df.iterrows():
            self.Row_Data(row)

# %%
# Reading images from local storage
starting_time = time.time()

data = Data(df,resize_x,resize_y)
data.Get_Data()

ending_time = time.time()
total_time = ending_time - starting_time
total_time/=60

print("Time taken to read images : ",total_time," min")
# Out:
# Time taken to read images :  0.9632343967755636  min

# %%
# Up-sampling the images

starting_time = time.time()
#Storing in dictionary
classes = {}

for val in range(num_of_classes):
    classes[val]=[]

max_repeating = 0;

for i,label in enumerate(data.Y):
    classes[label].append(data.X[i])

for key in classes:
    max_repeating = max(max_repeating,len(classes[key]))

for i in range(num_of_classes):
    length = len(classes[i])
    upsample_count = max_repeating - length
    for j in range(upsample_count):
        select_image = random.randint(0,length-1)
        angle = random.randint(0,359)
        classes[i].append(classes[i][select_image].rotate(angle).resize((resize_x,resize_y)))

ending_time = time.time()
total_time = ending_time - starting_time
total_time/=60

print("Time taken to upsample images : ",total_time," min")
# Out:
# Time taken to upsample images :  0.07081675926844279  min

# %%
# Up-sampling example image

random_class = random.randint(0,num_of_classes)
length = len(classes[random_class])
random_image = random.randint(0,length-1)
img = classes[random_class][random_image]
fig, axes = plt.subplots(1, 2, figsize=(10, 20))
ax = axes[0]
axes[0].set_title(f' Original Image')
ax.imshow(img)
angle = random.randint(1,359)
img = img.rotate(angle).resize((resize_x,resize_y))
axes[1].imshow(img)
axes[1].set_title(f' Rotated Version')
ax.axis('off')
# Out:
# (-0.5, 14.5, 14.5, -0.5)

# %%
x_labels = [str(x) for x in range(num_of_classes)]
y_labels = []
for i in (classes):
    y_labels.append(len(classes[i]))
plt.figure(figsize=(15, 6))
plt.bar(x_labels,y_labels,width=0.5)
plt.title('Bar Graph')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Declaring X_train and Y_train and Re arranging the values

starting_time = time.time()

X_train = []
Y_train = []

for i in range(num_of_classes):
    for j,val in enumerate(classes[i]):
        X_train.append(np.array(val))
        Y_train.append(i)

array_pairs = list(zip(X_train, Y_train))

# Shuffle the pairs
shuffled_pairs = np.random.permutation(array_pairs)

X_train, Y_train = zip(*shuffled_pairs)

X_train = tf.convert_to_tensor(np.array(X_train),dtype=float)
Y_train = tf.convert_to_tensor(np.array(Y_train),dtype=float)


ending_time = time.time()
total_time = ending_time - starting_time
total_time/=60

print("Time taken to convert into tensor : ",total_time," min")
# Out:
# C:\Users\gajul\AppData\Local\Temp\ipykernel_9932\170726535.py:16: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   shuffled_pairs = np.random.permutation(array_pairs)
# Time taken to convert into tensor :  0.04480001926422119  min

# %%
fig, axes = plt.subplots(1, 5, figsize=(10, 20))
length = len(X_train)
for i in range(5):
    col=i
    ax = axes[col]
    random_integer = random.randint(0,length-1)
    img = X_train[random_integer]
    ax.imshow(img)
    ax.set_title(f'Image {i + 1}')
    ax.axis('off')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#Data_Augmentation
X_train = X_train/255.0

# %%
Y_train = to_categorical(Y_train)

# %%
# Implementation of ANN
model = Sequential([
    Conv2D(16, (3, 3), activation='relu', input_shape=(resize_x, resize_y, num_of_channels)),
    MaxPooling2D((2, 2)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(128, activation='relu'),
    Dense(512, activation='sigmoid'),
    Dense(num_of_classes, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
starting_time = time.time()

history = model.fit(X_train,Y_train,epochs=Epochs,batch_size=32,validation_split=0.3)

ending_time = time.time()
total_time = ending_time - starting_time
total_time/=60

print("Time taken fit : ",total_time," min")
# Out:
# Epoch 1/50
# 2117/2117 [==============================] - 14s 6ms/step - loss: 1.9645 - accuracy: 0.3875 - val_loss: 1.3288 - val_accuracy: 0.5550
# Epoch 2/50
# 2117/2117 [==============================] - 15s 7ms/step - loss: 1.0070 - accuracy: 0.6705 - val_loss: 0.8603 - val_accuracy: 0.7212
# Epoch 3/50
# 2117/2117 [==============================] - 16s 8ms/step - loss: 0.7236 - accuracy: 0.7642 - val_loss: 0.6373 - val_accuracy: 0.7974
# Epoch 4/50
# 2117/2117 [==============================] - 15s 7ms/step - loss: 0.5601 - accuracy: 0.8172 - val_loss: 0.5380 - val_accuracy: 0.8271
# Epoch 5/50
# 2117/2117 [==============================] - 16s 8ms/step - loss: 0.4523 - accuracy: 0.8520 - val_loss: 0.4471 - val_accuracy: 0.8565
# Epoch 6/50
# 2117/2117 [==============================] - 15s 7ms/step - loss: 0.3766 - accuracy: 0.8774 - val_loss: 0.3961 - val_accuracy: 0.8752
# Epoch 7/50
# 2117/2117 [==============================] - 16s 8ms/step - loss: 0.3232 - accuracy: 0.8936 - val_loss: 0.3561 - val_accuracy: 0.8864
# Epoch 8/50
# 2117/2117 [==============================] - 16s 8ms/step - loss: 0.2795 - accuracy: 0.9074 - val_loss: 0.3195 - val_accuracy: 0.8973
# Epoch 9/50
# 2117/2117 [==============================] - 17s 8ms/step - loss: 0.2519 - accuracy: 0.9153 - val_loss: 0.2814 - val_accuracy: 0.9093
# Epoch 10/50
# 2117/2117 [==============================] - 16s 7ms/step - loss: 0.2233 - accuracy: 0.9263 - val_loss: 0.2778 - val_accuracy: 0.9125
# Epoch 11/50
# 2117/2117 [==============================] - 17s 8ms/step - loss: 0.2055 - accuracy: 0.9306 - val_loss: 0.2782 - val_accuracy: 0.9130
# Epoch 12/50
# 2117/2117 [==============================] - 16s 8ms/step - loss: 0.1870 - accuracy: 0.9369 - val_loss: 0.2708 - val_accuracy: 0.9167
# Epoch 13/50
# 2117/2117 [==============================] - 16s 7ms/step - loss: 0.1692 - accuracy: 0.9426 - val_loss: 0.2425 - val_accuracy: 0.9251
# Epoch 14/50
# 2117/2117 [==============================] - 16s 8ms/step - loss: 0.1562 - accuracy: 0.9466 - val_loss: 0.2752 - val_accuracy: 0.9150
# Epoch 15/50
# 2117/2117 [==============================] - 17s 8ms/step - loss: 0.1480 - accuracy: 0.9499 - val_loss: 0.2663 - val_accuracy: 0.9204
# Epoch 16/50
# 2117/2117 [==============================] - 18s 8ms/step - loss: 0.1363 - accuracy: 0.9539 - val_loss: 0.2834 - val_accuracy: 0.9134
# Epoch 17/50
# 2117/2117 [==============================] - 18s 9ms/step - loss: 0.1304 - accuracy: 0.9552 - val_loss: 0.2465 - val_accuracy: 0.9274
# Epoch 18/50
# 2117/2117 [==============================] - 17s 8ms/step - loss: 0.1185 - accuracy: 0.9591 - val_loss: 0.2423 - val_accuracy: 0.9270
# Epoch 19/50
# 2117/2117 [==============================] - 17s 8ms/step - loss: 0.1129 - accuracy: 0.9615 - val_loss: 0.2437 - val_accuracy: 0.9288
# Epoch 20/50
# 2117/2117 [==============================] - 17s 8ms/step - loss: 0.1095 - accuracy: 0.9628 - val_loss: 0.2325 - val_accuracy: 0.9327
# Epoch 21/50
# 2117/2117 [==============================] - 17s 8ms/step - loss: 0.0994 - accuracy: 0.9660 - val_loss: 0.2196 - val_accuracy: 0.9345
# Epoch 22/50
# 2117/2117 [==============================] - 18s 8ms/step - loss: 0.0957 - accuracy: 0.9666 - val_loss: 0.2438 - val_accuracy: 0.9306
# Epoch 23/50
# 2117/2117 [==============================] - 19s 9ms/step - loss: 0.0959 - accuracy: 0.9669 - val_loss: 0.2347 - val_accuracy: 0.9339
# Epoch 24/50
# 2117/2117 [==============================] - 17s 8ms/step - loss: 0.0868 - accuracy: 0.9701 - val_loss: 0.2282 - val_accuracy: 0.9332
# Epoch 25/50
# 2117/2117 [==============================] - 17s 8ms/step - loss: 0.0873 - accuracy: 0.9700 - val_loss: 0.2181 - val_accuracy: 0.9376
# Epoch 26/50
# 2117/2117 [==============================] - 17s 8ms/step - loss: 0.0814 - accuracy: 0.9720 - val_loss: 0.2757 - val_accuracy: 0.9230
# Epoch 27/50
# 2117/2117 [==============================] - 16s 7ms/step - loss: 0.0795 - accuracy: 0.9733 - val_loss: 0.2700 - val_accuracy: 0.9263
# Epoch 28/50
# 2117/2117 [==============================] - 17s 8ms/step - loss: 0.0771 - accuracy: 0.9729 - val_loss: 0.2304 - val_accuracy: 0.9377
# Epoch 29/50
# 2117/2117 [==============================] - 18s 8ms/step - loss: 0.0744 - accuracy: 0.9746 - val_loss: 0.2285 - val_accuracy: 0.9371
# Epoch 30/50
# 2117/2117 [==============================] - 18s 8ms/step - loss: 0.0715 - accuracy: 0.9752 - val_loss: 0.2202 - val_accuracy: 0.9407
# Epoch 31/50
# 2117/2117 [==============================] - 19s 9ms/step - loss: 0.0713 - accuracy: 0.9746 - val_loss: 0.2106 - val_accuracy: 0.9442
# Epoch 32/50
# 2117/2117 [==============================] - 15s 7ms/step - loss: 0.0763 - accuracy: 0.9739 - val_loss: 0.2481 - val_accuracy: 0.9321
# Epoch 33/50
# 2117/2117 [==============================] - 16s 8ms/step - loss: 0.0680 - accuracy: 0.9767 - val_loss: 0.2256 - val_accuracy: 0.9391
# Epoch 34/50
# 2117/2117 [==============================] - 15s 7ms/step - loss: 0.0652 - accuracy: 0.9771 - val_loss: 0.2194 - val_accuracy: 0.9438
# Epoch 35/50
# 2117/2117 [==============================] - 18s 8ms/step - loss: 0.0619 - accuracy: 0.9795 - val_loss: 0.2802 - val_accuracy: 0.9257
# Epoch 36/50
# 2117/2117 [==============================] - 17s 8ms/step - loss: 0.0689 - accuracy: 0.9766 - val_loss: 0.2382 - val_accuracy: 0.9376
# Epoch 37/50
# 2117/2117 [==============================] - 17s 8ms/step - loss: 0.0629 - accuracy: 0.9786 - val_loss: 0.2712 - val_accuracy: 0.9297
# Epoch 38/50
# 2117/2117 [==============================] - 18s 8ms/step - loss: 0.0611 - accuracy: 0.9784 - val_loss: 0.2234 - val_accuracy: 0.9398
# Epoch 39/50
# 2117/2117 [==============================] - 18s 9ms/step - loss: 0.0615 - accuracy: 0.9788 - val_loss: 0.2396 - val_accuracy: 0.9387
# Epoch 40/50
# 2117/2117 [==============================] - 15s 7ms/step - loss: 0.0623 - accuracy: 0.9783 - val_loss: 0.2128 - val_accuracy: 0.9456
# Epoch 41/50
# 2117/2117 [==============================] - 15s 7ms/step - loss: 0.0570 - accuracy: 0.9809 - val_loss: 0.2472 - val_accuracy: 0.9383
# Epoch 42/50
# 2117/2117 [==============================] - 15s 7ms/step - loss: 0.0619 - accuracy: 0.9784 - val_loss: 0.2214 - val_accuracy: 0.9431
# Epoch 43/50
# 2117/2117 [==============================] - 16s 8ms/step - loss: 0.0555 - accuracy: 0.9809 - val_loss: 0.2246 - val_accuracy: 0.9426
# Epoch 44/50
# 2117/2117 [==============================] - 18s 9ms/step - loss: 0.0609 - accuracy: 0.9794 - val_loss: 0.2607 - val_accuracy: 0.9334
# Epoch 45/50
# 2117/2117 [==============================] - 18s 8ms/step - loss: 0.0540 - accuracy: 0.9814 - val_loss: 0.2581 - val_accuracy: 0.9358
# Epoch 46/50
# 2117/2117 [==============================] - 17s 8ms/step - loss: 0.0584 - accuracy: 0.9801 - val_loss: 0.2558 - val_accuracy: 0.9382
# Epoch 47/50
# 2117/2117 [==============================] - 16s 8ms/step - loss: 0.0592 - accuracy: 0.9802 - val_loss: 0.2386 - val_accuracy: 0.9398
# Epoch 48/50
# 2117/2117 [==============================] - 18s 8ms/step - loss: 0.0523 - accuracy: 0.9826 - val_loss: 0.2421 - val_accuracy: 0.9405
# Epoch 49/50
# 2117/2117 [==============================] - 19s 9ms/step - loss: 0.0573 - accuracy: 0.9803 - val_loss: 0.2971 - val_accuracy: 0.9303
# Epoch 50/50
# 2117/2117 [==============================] - 18s 8ms/step - loss: 0.0547 - accuracy: 0.9813 - val_loss: 0.2415 - val_accuracy: 0.9406
# Time taken fit :  13.928832562764486  min

# %%
model.save("CNN_Model")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: CNN_Model\assets
# INFO:tensorflow:Assets written to: CNN_Model\assets

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs  = [x for x in range(Epochs)]
plt.figure(figsize=(10,5))
plt.plot(epochs,training_accuracy,color="blue",label="Training Accuracy")
plt.plot(epochs,validation_accuracy,color="red",label="Validation Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %%
epochs  = [x for x in range(Epochs)]
plt.figure(figsize=(10,5))
plt.plot(epochs,loss,color="blue",label="training loss")
plt.plot(epochs,val_loss,color="red",label="validation loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %% [markdown]
#  ***Test Image Classification and Accuracy Calculation***

# %%
model = tf.keras.models.load_model("CNN_Model")

# %%
df_test = pd.read_csv("./germany_dataset/test.csv")
print("Number of Test Images are ", len(df_test))
df_test.head()
# Out:
# Number of Test Images are  12630
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId            Path
# 0     53      54       6       5      48      49       16  Test/00000.png
# 1     42      45       5       5      36      40        1  Test/00001.png
# 2     48      52       6       6      43      47       38  Test/00002.png
# 3     27      29       5       5      22      24       33  Test/00003.png
# 4     60      57       5       5      55      52       11  Test/00004.png

# %%
# Sample Images and there crop according to data given in test.csv
num_rows = 5
num_cols = 2
test_length = len(df_test.values)
fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 20))
total_images = []
for i in range(5):
    integer = random.randint(0,test_length-1)
    total_images.append(df_test.iloc[integer].values)
total_images = list(total_images)
for i,val in enumerate(total_images):
    row = i
    col=0
    ax = axes[row, col]
    img = Image.open(directory+val[7])
    ax.imshow(img)
    ax.set_title(f'Image {i + 1}')
    img = img.crop((val[2],val[3],val[4],val[5]))
    ax = axes[row,col+1]
    ax.imshow(img)
    ax.set_title(f'Image {i + 1} [Crop]')
    ax.axis('off')

# %%
# Test Images Prediction

images = []
for row in df_test.values:
    img = Image.open(directory+row[7])
    img = img.crop((row[2],row[3],row[4],row[5]))
    img = img.resize((resize_x,resize_y))
    img = np.array(img)
    images.append(img)
y_predicted = Predict_for_Multiple_examples(model,images)
# Out:
# 395/395 [==============================] - 1s 3ms/step

# %%
# Test Accuracy Determination

y_test = df_test.iloc[:,6].values
total_correct = 0;
for i in range(test_length):
    if y_predicted[i] == y_test[i]:
        total_correct=total_correct+1
accuracy = total_correct/test_length
print("Final Test Accuracy : ",accuracy*100," %")
# Out:
# Final Test Accuracy :  85.94615993665874  %

# %%
# Testing one Random Image from test data 

select_row=random.randint(0,test_length-1)
row = df_test.iloc[select_row]
print("Original Value : ",df_test.iloc[select_row,6])
img = Image.open(directory+row[7])
img = img.crop((row[2],row[3],row[4],row[5]))
img = img.resize((resize_x,resize_y))
plt.imshow(img)
img  = np.array(img)
img  = tf.convert_to_tensor(img,dtype=float)
img = img/255.0
img = tf.expand_dims(img, axis=0)
probability = model.predict(img)
value = get_max_index(probability[0])
print("Predicted Value : ",value)
# Out:
# Original Value :  38
# 1/1 [==============================] - 0s 27ms/step
# Predicted Value :  35
